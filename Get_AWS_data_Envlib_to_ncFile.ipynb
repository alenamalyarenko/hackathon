# %% [markdown]
# # Get AWS data from Envlib.org API - Tethys

# %% [markdown]
# https://www.envlib.org

# %% [markdown]
# This notebook takes AWS data from 2 stations using envlib data and saves the data into netcdf files for use in subsequent analysis. The notebook uses the pythoin API in https://tethysts.readthedocs.io

# %% [raw]
# For this notebook to work make sure the kernel is set for tethys.
#
# The notebook will do the following:
#
# 1. "USER INPUTS" User inputs the station ID found from the Dscovery Tool on www.envlib.org. This can be achieved by selcxting an owner for the weather station and then using the station location map to clisk on the desired station. The station ID can then be found under the Station Data tab. For example, the station ID for Matawai in the Gisborne region is "f09a8a487f3c7ba83f3cdb1a"
#
# 2. "GET MET DATA" Get the meteorlogical data from all the available time periods for this particular station and store it into an xarray dataset
#
# 3. "SAVEto NETCDF" Save the output into a netcdf file
#
# If more than one sttaion data is required then you will need to rerun this notebook and produce another netcdf file.

# %% [markdown]
# ## Import Libraries

# %%
import xarray as xr
from tethysts import Tethys # import the Tethys class

# %%
! pwd
# Out:
# /home/UOCNT/ama677/hackathon

# %%
# create a tethys instance and get datasets
ts=Tethys(cache="/home/UOCNT/ama677/cache")
datasets = ts.datasets

# %%
datasets
# Out:
# [{'feature': 'waterway',
#   'parameter': 'oxygen_dissolved',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '24H',
#   'utc_offset': '12H',
#   'dataset_id': '936a8ac83264502c0d388001',
#   'units': 'mg/l',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.11636, -40.62673],
#      [176.11636, -39.80943],
#      [175.17461, -39.80943],
#      [175.17461, -40.62673],
#      [176.11636, -40.62673]]]},
#   'time_range': {'from_date': '2011-07-06T12:00:00',
#    'to_date': '2023-08-17T12:00:00'},
#   'precision': 0.01,
#   'properties': {'encoding': {'oxygen_dissolved': {'scale_factor': 0.01,
#      'dtype': 'int16',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'waterway',
#   'parameter': 'turbidity',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '24H',
#   'utc_offset': '12H',
#   'dataset_id': '0e6c09f32e0394deac5ce99b',
#   'units': 'FNU',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.3106, -40.63382],
#      [176.3106, -38.78583],
#      [175.03236, -38.78583],
#      [175.03236, -40.63382],
#      [176.3106, -40.63382]]]},
#   'time_range': {'from_date': '2010-06-08T12:00:00',
#    'to_date': '2022-07-30T12:00:00'},
#   'cf_standard_name': 'sea_water_turbidity',
#   'precision': 0.001,
#   'properties': {'encoding': {'turbidity': {'scale_factor': 0.001,
#      'dtype': 'int32',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'waterway',
#   'parameter': 'gage_height',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '1H',
#   'utc_offset': '0H',
#   'dataset_id': '37cd93b95cacde6c8496c438',
#   'units': 'm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.55861, -41.51137],
#      [176.55861, -38.60342],
#      [173.07304, -38.60342],
#      [173.07304, -41.51137],
#      [176.55861, -41.51137]]]},
#   'time_range': {'from_date': '1972-12-30T17:00:00',
#    'to_date': '2022-07-30T08:00:00'},
#   'cf_standard_name': 'water_surface_height_above_reference_datum',
#   'precision': 0.001,
#   'properties': {'encoding': {'gage_height': {'scale_factor': 0.001,
#      'dtype': 'int16',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 7300}},
#  {'feature': 'groundwater',
#   'parameter': 'groundwater_depth',
#   'method': 'sensor_recording',
#   'product_code': 'raw_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '24H',
#   'utc_offset': '12H',
#   'dataset_id': '90006c8dcf47ed6799fe764b',
#   'units': 'm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[175.7629, -40.66938],
#      [175.7629, -40.07008],
#      [175.15967, -40.07008],
#      [175.15967, -40.66938],
#      [175.7629, -40.66938]]]},
#   'time_range': {'from_date': '2022-06-12T12:00:00',
#    'to_date': '2022-07-11T12:00:00'},
#   'cf_standard_name': 'water_table_depth',
#   'precision': 0.001,
#   'properties': {'encoding': {'groundwater_depth': {'scale_factor': 0.001,
#      'dtype': 'int32',
#      '_FillValue': -9999},
#     'quality_code': {'dtype': 'int16', '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'atmosphere',
#   'parameter': 'precipitation',
#   'method': 'sensor_recording',
#   'product_code': 'raw_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'cumulative',
#   'frequency_interval': '1H',
#   'utc_offset': '0H',
#   'dataset_id': 'fc219e06d4c26d4f48c65ed5',
#   'units': 'mm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.19687, -40.40484],
#      [176.19687, -39.01141],
#      [174.76285, -39.01141],
#      [174.76285, -40.40484],
#      [176.19687, -40.40484]]]},
#   'time_range': {'from_date': '2022-06-21T16:00:00',
#    'to_date': '2022-07-11T21:00:00'},
#   'cf_standard_name': 'precipitation_amount',
#   'precision': 0.1,
#   'properties': {'encoding': {'precipitation': {'scale_factor': 0.1,
#      'dtype': 'int16',
#      '_FillValue': -99},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 7300}},
#  {'feature': 'waterway',
#   'parameter': 'temperature',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '1H',
#   'utc_offset': '0H',
#   'dataset_id': 'a4846515397b22d824d9fc29',
#   'units': 'degC',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.32225, -40.76986],
#      [176.32225, -38.78583],
#      [174.90105, -38.78583],
#      [174.90105, -40.76986],
#      [176.32225, -40.76986]]]},
#   'time_range': {'from_date': '1977-02-06T18:00:00',
#    'to_date': '2023-08-18T10:00:00'},
#   'cf_standard_name': 'sea_water_temperature',
#   'precision': 0.01,
#   'properties': {'encoding': {'temperature': {'scale_factor': 0.01,
#      'dtype': 'int16',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 7300}},
#  {'feature': 'waterway',
#   'parameter': 'temperature',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'continuous',
#   'frequency_interval': 'None',
#   'utc_offset': '0H',
#   'dataset_id': '8b078e648cc8d61a67c2a5d9',
#   'units': 'degC',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.32225, -40.76986],
#      [176.32225, -38.78583],
#      [174.90105, -38.78583],
#      [174.90105, -40.76986],
#      [176.32225, -40.76986]]]},
#   'time_range': {'from_date': '1977-02-06T18:56:00',
#    'to_date': '2023-08-18T10:15:00'},
#   'cf_standard_name': 'sea_water_temperature',
#   'precision': 0.01,
#   'properties': {'encoding': {'temperature': {'scale_factor': 0.01,
#      'dtype': 'int16',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 3650}},
#  {'feature': 'waterway',
#   'parameter': 'streamflow',
#   'method': 'field_activity',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'sporadic',
#   'frequency_interval': 'None',
#   'utc_offset': '0H',
#   'dataset_id': '1b8bf38bc7b57ec7d6cc1eff',
#   'units': 'm^3/s',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.51669, -40.91732],
#      [176.51669, -38.51113],
#      [174.80694, -38.51113],
#      [174.80694, -40.91732],
#      [176.51669, -40.91732]]]},
#   'time_range': {'from_date': '1948-03-04T00:00:00',
#    'to_date': '2023-06-22T01:32:00'},
#   'cf_standard_name': 'water_volume_transport_in_river_channel',
#   'precision': 0.0001,
#   'properties': {'encoding': {'streamflow': {'scale_factor': 0.0001,
#      'dtype': 'int32',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'waterway',
#   'parameter': 'oxygen_dissolved',
#   'method': 'field_activity',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'sporadic',
#   'frequency_interval': 'None',
#   'utc_offset': '0H',
#   'dataset_id': '4b145792cb8a77e9b1653efa',
#   'units': 'mg/l',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.42265, -40.7375],
#      [176.42265, -38.78583],
#      [174.8965, -38.78583],
#      [174.8965, -40.7375],
#      [176.42265, -40.7375]]]},
#   'time_range': {'from_date': '1989-04-11T21:40:00',
#    'to_date': '2022-02-23T22:24:00'},
#   'precision': 0.01,
#   'properties': {'encoding': {'oxygen_dissolved': {'scale_factor': 0.01,
#      'dtype': 'int16',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'waterway',
#   'parameter': 'velocity',
#   'method': 'field_activity',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'sporadic',
#   'frequency_interval': 'None',
#   'utc_offset': '0H',
#   'dataset_id': '195a28e73dd02d311842cc88',
#   'units': 'm/s',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.51669, -40.91732],
#      [176.51669, -38.51113],
#      [174.80694, -38.51113],
#      [174.80694, -40.91732],
#      [176.51669, -40.91732]]]},
#   'time_range': {'from_date': '1948-03-04T00:00:00',
#    'to_date': '2023-06-22T01:32:00'},
#   'precision': 0.001,
#   'properties': {'encoding': {'velocity': {'scale_factor': 0.001,
#      'dtype': 'int16',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'waterway',
#   'parameter': 'nitrogen_nitrate',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '24H',
#   'utc_offset': '12H',
#   'dataset_id': '2fbe50184ebc073ad8c9b93a',
#   'units': 'mg/l',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[175.24726, -40.62673],
#      [175.24726, -40.60588],
#      [175.23727, -40.60588],
#      [175.23727, -40.62673],
#      [175.24726, -40.62673]]]},
#   'time_range': {'from_date': '2021-12-19T12:00:00',
#    'to_date': '2023-08-17T12:00:00'},
#   'precision': 0.001,
#   'properties': {'encoding': {'nitrogen_nitrate': {'scale_factor': 0.001,
#      'dtype': 'int32',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'waterway',
#   'parameter': 'turbidity',
#   'method': 'field_activity',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'sporadic',
#   'frequency_interval': 'None',
#   'utc_offset': '0H',
#   'dataset_id': '958b2afef34154bcfa423185',
#   'units': 'NTU',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.42265, -40.72439],
#      [176.42265, -38.78583],
#      [174.89982, -38.78583],
#      [174.89982, -40.72439],
#      [176.42265, -40.72439]]]},
#   'time_range': {'from_date': '1989-09-26T21:18:00',
#    'to_date': '2022-02-20T08:01:00'},
#   'precision': 0.01,
#   'properties': {'encoding': {'turbidity': {'scale_factor': 0.01,
#      'dtype': 'int32',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'waterway',
#   'parameter': 'streamflow',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'continuous',
#   'frequency_interval': 'None',
#   'utc_offset': '0H',
#   'dataset_id': 'e4fe750041a69b8481f18a8d',
#   'units': 'm^3/s',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.51669, -41.34899],
#      [176.51669, -38.60342],
#      [173.07304, -38.60342],
#      [173.07304, -41.34899],
#      [176.51669, -41.34899]]]},
#   'time_range': {'from_date': '1972-12-30T14:00:00',
#    'to_date': '2023-08-17T18:45:00'},
#   'cf_standard_name': 'water_volume_transport_in_river_channel',
#   'precision': 0.0001,
#   'properties': {'encoding': {'streamflow': {'scale_factor': 0.0001,
#      'dtype': 'int32',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 3650}},
#  {'feature': 'still_waters',
#   'parameter': 'temperature',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'continuous',
#   'frequency_interval': 'None',
#   'utc_offset': '0H',
#   'dataset_id': '077f21d1d8b873e2191a27e9',
#   'units': 'degC',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[175.23845, -40.64659],
#      [175.23845, -40.60585],
#      [175.22345, -40.60585],
#      [175.22345, -40.64659],
#      [175.23845, -40.64659]]]},
#   'time_range': {'from_date': '2018-12-31T12:00:00',
#    'to_date': '2022-07-14T05:00:00'},
#   'cf_standard_name': 'sea_water_temperature',
#   'precision': 0.01,
#   'properties': {'encoding': {'temperature': {'scale_factor': 0.01,
#      'dtype': 'int16',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 3650}},
#  {'feature': 'waterway',
#   'parameter': 'gage_height',
#   'method': 'sensor_recording',
#   'product_code': 'raw_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '24H',
#   'utc_offset': '12H',
#   'dataset_id': 'cbfd389d52b904172dab35ae',
#   'units': 'm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.55861, -41.51137],
#      [176.55861, -38.78583],
#      [173.95389, -38.78583],
#      [173.95389, -41.51137],
#      [176.55861, -41.51137]]]},
#   'time_range': {'from_date': '2022-06-12T12:00:00',
#    'to_date': '2022-07-11T12:00:00'},
#   'cf_standard_name': 'water_surface_height_above_reference_datum',
#   'precision': 0.001,
#   'properties': {'encoding': {'gage_height': {'scale_factor': 0.001,
#      'dtype': 'int16',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'waterway',
#   'parameter': 'gage_height',
#   'method': 'field_activity',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'sporadic',
#   'frequency_interval': 'None',
#   'utc_offset': '0H',
#   'dataset_id': '62cf0e9a5b8d0a6a9863bd06',
#   'units': 'mm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.51669, -40.91732],
#      [176.51669, -38.51113],
#      [174.80694, -38.51113],
#      [174.80694, -40.91732],
#      [176.51669, -40.91732]]]},
#   'time_range': {'from_date': '1952-02-20T00:30:00',
#    'to_date': '2023-06-22T01:32:00'},
#   'cf_standard_name': 'water_surface_height_above_reference_datum',
#   'precision': 0.001,
#   'properties': {'encoding': {'gage_height': {'scale_factor': 0.001,
#      'dtype': 'int16',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'waterway',
#   'parameter': 'streamflow',
#   'method': 'sensor_recording',
#   'product_code': 'raw_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '24H',
#   'utc_offset': '12H',
#   'dataset_id': '2f6610241fa82d9e80c915c2',
#   'units': 'm^3/s',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.39452, -40.72439],
#      [176.39452, -38.78583],
#      [174.80694, -38.78583],
#      [174.80694, -40.72439],
#      [176.39452, -40.72439]]]},
#   'time_range': {'from_date': '2022-06-12T12:00:00',
#    'to_date': '2022-07-11T12:00:00'},
#   'cf_standard_name': 'water_volume_transport_in_river_channel',
#   'precision': 0.0001,
#   'properties': {'encoding': {'streamflow': {'scale_factor': 0.0001,
#      'dtype': 'int32',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'groundwater',
#   'parameter': 'water_level',
#   'method': 'field_activity',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'sporadic',
#   'frequency_interval': 'None',
#   'utc_offset': '0H',
#   'dataset_id': '9a4f6a511a597ea6af8bbd9e',
#   'units': 'm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.03085, -40.71081],
#      [176.03085, -39.86924],
#      [174.89731, -39.86924],
#      [174.89731, -40.71081],
#      [176.03085, -40.71081]]]},
#   'time_range': {'from_date': '1990-07-05T02:25:00',
#    'to_date': '2023-08-17T15:00:00'},
#   'cf_standard_name': 'water_table_depth',
#   'precision': 0.001,
#   'description': 'The water level datum is above mean sea level.',
#   'properties': {'encoding': {'water_level': {'scale_factor': 0.001,
#      'dtype': 'int32',
#      '_FillValue': -999999},
#     'quality_code': {'dtype': 'int16', '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'waterway',
#   'parameter': 'oxygen_dissolved',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'continuous',
#   'frequency_interval': 'None',
#   'utc_offset': '0H',
#   'dataset_id': '02b86c41b29cbc055f6796ef',
#   'units': 'mg/l',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.11636, -40.62673],
#      [176.11636, -39.80943],
#      [175.17461, -39.80943],
#      [175.17461, -40.62673],
#      [176.11636, -40.62673]]]},
#   'time_range': {'from_date': '2011-07-07T04:00:00',
#    'to_date': '2023-08-18T09:30:00'},
#   'precision': 0.01,
#   'properties': {'encoding': {'oxygen_dissolved': {'scale_factor': 0.01,
#      'dtype': 'int16',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 3650}},
#  {'feature': 'still_waters',
#   'parameter': 'turbidity',
#   'method': 'field_activity',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'sporadic',
#   'frequency_interval': 'None',
#   'utc_offset': '0H',
#   'dataset_id': 'ce6f0cea34ee777c5fea5dae',
#   'units': 'NTU',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[175.29233, -40.64659],
#      [175.29233, -39.97179],
#      [175.09436, -39.97179],
#      [175.09436, -40.64659],
#      [175.29233, -40.64659]]]},
#   'time_range': {'from_date': '1991-11-06T12:00:00',
#    'to_date': '2021-12-19T23:25:00'},
#   'precision': 0.01,
#   'properties': {'encoding': {'turbidity': {'scale_factor': 0.01,
#      'dtype': 'int32',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'waterway',
#   'parameter': 'gage_height',
#   'method': 'sensor_recording',
#   'product_code': 'raw_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'continuous',
#   'frequency_interval': 'None',
#   'utc_offset': '0H',
#   'dataset_id': '5e3959d37130aa7a9117dcb8',
#   'units': 'm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.55861, -41.51137],
#      [176.55861, -38.78583],
#      [173.95389, -38.78583],
#      [173.95389, -41.51137],
#      [176.55861, -41.51137]]]},
#   'time_range': {'from_date': '2022-06-13T11:30:00',
#    'to_date': '2022-07-11T21:15:00'},
#   'cf_standard_name': 'water_surface_height_above_reference_datum',
#   'precision': 0.001,
#   'properties': {'encoding': {'gage_height': {'scale_factor': 0.001,
#      'dtype': 'int16',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 3650}},
#  {'feature': 'waterway',
#   'parameter': 'oxygen_dissolved',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '1H',
#   'utc_offset': '0H',
#   'dataset_id': 'f91334885e9a0eccf28c1f7c',
#   'units': 'mg/l',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.11636, -40.62673],
#      [176.11636, -39.80943],
#      [175.17461, -39.80943],
#      [175.17461, -40.62673],
#      [176.11636, -40.62673]]]},
#   'time_range': {'from_date': '2011-07-07T04:00:00',
#    'to_date': '2023-08-18T09:00:00'},
#   'precision': 0.01,
#   'properties': {'encoding': {'oxygen_dissolved': {'scale_factor': 0.01,
#      'dtype': 'int16',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 7300}},
#  {'feature': 'atmosphere',
#   'parameter': 'precipitation',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'cumulative',
#   'frequency_interval': '24H',
#   'utc_offset': '12H',
#   'dataset_id': '9b220417ff6188fa893853d4',
#   'units': 'mm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.30051, -40.93467],
#      [176.30051, -38.66561],
#      [174.28918, -38.66561],
#      [174.28918, -40.93467],
#      [176.30051, -40.93467]]]},
#   'time_range': {'from_date': '1972-07-29T12:00:00',
#    'to_date': '2023-08-18T12:00:00'},
#   'cf_standard_name': 'precipitation_amount',
#   'precision': 0.1,
#   'properties': {'encoding': {'precipitation': {'scale_factor': 0.1,
#      'dtype': 'int16',
#      '_FillValue': -99},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'atmosphere',
#   'parameter': 'precipitation',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'cumulative',
#   'frequency_interval': '1H',
#   'utc_offset': '0H',
#   'dataset_id': '3024e52dc47411c7a9929583',
#   'units': 'mm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.30051, -40.93467],
#      [176.30051, -38.66561],
#      [174.28918, -38.66561],
#      [174.28918, -40.93467],
#      [176.30051, -40.93467]]]},
#   'time_range': {'from_date': '1972-07-30T11:00:00',
#    'to_date': '2023-08-18T14:00:00'},
#   'cf_standard_name': 'precipitation_amount',
#   'precision': 0.1,
#   'properties': {'encoding': {'precipitation': {'scale_factor': 0.1,
#      'dtype': 'int16',
#      '_FillValue': -99},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 7300}},
#  {'feature': 'groundwater',
#   'parameter': 'temperature',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '1H',
#   'utc_offset': '0H',
#   'dataset_id': 'a0c3a79a263f198e7412e485',
#   'units': 'degC',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[175.45835, -40.51955],
#      [175.45835, -40.46814],
#      [175.40793, -40.46814],
#      [175.40793, -40.51955],
#      [175.45835, -40.51955]]]},
#   'time_range': {'from_date': '2018-12-31T12:00:00',
#    'to_date': '2023-08-18T13:00:00'},
#   'cf_standard_name': 'sea_water_temperature',
#   'precision': 0.01,
#   'properties': {'encoding': {'temperature': {'scale_factor': 0.01,
#      'dtype': 'int16',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 7300}},
#  {'feature': 'atmosphere',
#   'parameter': 'precipitation',
#   'method': 'sensor_recording',
#   'product_code': 'raw_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'cumulative',
#   'frequency_interval': '24H',
#   'utc_offset': '12H',
#   'dataset_id': '843d3ac1c1159817dcf64343',
#   'units': 'mm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.19687, -40.40484],
#      [176.19687, -39.01141],
#      [174.76285, -39.01141],
#      [174.76285, -40.40484],
#      [176.19687, -40.40484]]]},
#   'time_range': {'from_date': '2022-06-21T12:00:00',
#    'to_date': '2022-07-11T12:00:00'},
#   'cf_standard_name': 'precipitation_amount',
#   'precision': 0.1,
#   'properties': {'encoding': {'precipitation': {'scale_factor': 0.1,
#      'dtype': 'int16',
#      '_FillValue': -99},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'waterway',
#   'parameter': 'nitrogen_nitrate',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'continuous',
#   'frequency_interval': 'None',
#   'utc_offset': '0H',
#   'dataset_id': '702b916b7fcf48962e014509',
#   'units': 'mg/l',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[175.24726, -40.62673],
#      [175.24726, -40.60588],
#      [175.23727, -40.60588],
#      [175.23727, -40.62673],
#      [175.24726, -40.62673]]]},
#   'time_range': {'from_date': '2021-12-20T02:15:00',
#    'to_date': '2023-08-18T09:30:00'},
#   'precision': 0.001,
#   'properties': {'encoding': {'nitrogen_nitrate': {'scale_factor': 0.001,
#      'dtype': 'int32',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 3650}},
#  {'feature': 'waterway',
#   'parameter': 'streamflow',
#   'method': 'sensor_recording',
#   'product_code': 'raw_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'continuous',
#   'frequency_interval': 'None',
#   'utc_offset': '0H',
#   'dataset_id': '3a63c085502d18021f364185',
#   'units': 'm^3/s',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.39452, -40.72439],
#      [176.39452, -38.78583],
#      [174.80694, -38.78583],
#      [174.80694, -40.72439],
#      [176.39452, -40.72439]]]},
#   'time_range': {'from_date': '2022-06-13T11:30:00',
#    'to_date': '2022-07-11T21:15:00'},
#   'cf_standard_name': 'water_volume_transport_in_river_channel',
#   'precision': 0.0001,
#   'properties': {'encoding': {'streamflow': {'scale_factor': 0.0001,
#      'dtype': 'int32',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 3650}},
#  {'feature': 'waterway',
#   'parameter': 'nitrogen_nitrate',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '1H',
#   'utc_offset': '0H',
#   'dataset_id': '8d42e8761b0c542c4de20dee',
#   'units': 'mg/l',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[175.24726, -40.62673],
#      [175.24726, -40.60588],
#      [175.23727, -40.60588],
#      [175.23727, -40.62673],
#      [175.24726, -40.62673]]]},
#   'time_range': {'from_date': '2021-12-20T02:00:00',
#    'to_date': '2023-08-18T09:00:00'},
#   'precision': 0.001,
#   'properties': {'encoding': {'nitrogen_nitrate': {'scale_factor': 0.001,
#      'dtype': 'int32',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 7300}},
#  {'feature': 'waterway',
#   'parameter': 'temperature',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '24H',
#   'utc_offset': '12H',
#   'dataset_id': '6a3198179298a13bf3c4fd20',
#   'units': 'degC',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.32225, -40.76986],
#      [176.32225, -38.78583],
#      [174.90105, -38.78583],
#      [174.90105, -40.76986],
#      [176.32225, -40.76986]]]},
#   'time_range': {'from_date': '1977-02-06T12:00:00',
#    'to_date': '2023-08-17T12:00:00'},
#   'cf_standard_name': 'sea_water_temperature',
#   'precision': 0.01,
#   'properties': {'encoding': {'temperature': {'scale_factor': 0.01,
#      'dtype': 'int16',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'waterway',
#   'parameter': 'streamflow',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '1H',
#   'utc_offset': '0H',
#   'dataset_id': '7499a7735e346a16dfeae13e',
#   'units': 'm^3/s',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.51669, -41.34899],
#      [176.51669, -38.60342],
#      [173.07304, -38.60342],
#      [173.07304, -41.34899],
#      [176.51669, -41.34899]]]},
#   'time_range': {'from_date': '1972-12-30T14:00:00',
#    'to_date': '2023-08-17T18:00:00'},
#   'cf_standard_name': 'water_volume_transport_in_river_channel',
#   'precision': 0.0001,
#   'properties': {'encoding': {'streamflow': {'scale_factor': 0.0001,
#      'dtype': 'int32',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 7300}},
#  {'feature': 'groundwater',
#   'parameter': 'temperature',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '24H',
#   'utc_offset': '12H',
#   'dataset_id': '04847a3ec6dba9bc3dd71889',
#   'units': 'degC',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[175.45835, -40.51955],
#      [175.45835, -40.46814],
#      [175.40793, -40.46814],
#      [175.40793, -40.51955],
#      [175.45835, -40.51955]]]},
#   'time_range': {'from_date': '2018-12-31T12:00:00',
#    'to_date': '2023-08-18T12:00:00'},
#   'cf_standard_name': 'sea_water_temperature',
#   'precision': 0.01,
#   'properties': {'encoding': {'temperature': {'scale_factor': 0.01,
#      'dtype': 'int16',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'waterway',
#   'parameter': 'gage_height',
#   'method': 'sensor_recording',
#   'product_code': 'raw_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '1H',
#   'utc_offset': '0H',
#   'dataset_id': 'a4921d02c96fccef1e04cbff',
#   'units': 'm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.55861, -41.51137],
#      [176.55861, -38.78583],
#      [173.95389, -38.78583],
#      [173.95389, -41.51137],
#      [176.55861, -41.51137]]]},
#   'time_range': {'from_date': '2022-06-13T11:00:00',
#    'to_date': '2022-07-11T21:00:00'},
#   'cf_standard_name': 'water_surface_height_above_reference_datum',
#   'precision': 0.001,
#   'properties': {'encoding': {'gage_height': {'scale_factor': 0.001,
#      'dtype': 'int16',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 7300}},
#  {'feature': 'groundwater',
#   'parameter': 'groundwater_depth',
#   'method': 'sensor_recording',
#   'product_code': 'raw_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '1H',
#   'utc_offset': '0H',
#   'dataset_id': '05402ee54ca297044cbf644a',
#   'units': 'm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[175.7629, -40.66938],
#      [175.7629, -40.07008],
#      [175.15967, -40.07008],
#      [175.15967, -40.66938],
#      [175.7629, -40.66938]]]},
#   'time_range': {'from_date': '2022-06-13T11:00:00',
#    'to_date': '2022-07-11T21:00:00'},
#   'cf_standard_name': 'water_table_depth',
#   'precision': 0.001,
#   'properties': {'encoding': {'groundwater_depth': {'scale_factor': 0.001,
#      'dtype': 'int32',
#      '_FillValue': -9999},
#     'quality_code': {'dtype': 'int16', '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 7300}},
#  {'feature': 'atmosphere',
#   'parameter': 'precipitation',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'cumulative',
#   'frequency_interval': 'None',
#   'utc_offset': '0H',
#   'dataset_id': '1555d4c0f26cbe0f19e248ab',
#   'units': 'mm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.30051, -40.93467],
#      [176.30051, -38.66561],
#      [174.28918, -38.66561],
#      [174.28918, -40.93467],
#      [176.30051, -40.93467]]]},
#   'time_range': {'from_date': '1972-12-30T20:00:00',
#    'to_date': '2022-07-14T07:30:00'},
#   'cf_standard_name': 'precipitation_amount',
#   'precision': 0.1,
#   'properties': {'encoding': {'precipitation': {'scale_factor': 0.1,
#      'dtype': 'int16',
#      '_FillValue': -99},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 3650}},
#  {'feature': 'waterway',
#   'parameter': 'gage_height',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Horizons Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '24H',
#   'utc_offset': '12H',
#   'dataset_id': '37c4642199810fe98923851e',
#   'units': 'm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Horizons Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[176.55861, -41.51137],
#      [176.55861, -38.60342],
#      [173.07304, -38.60342],
#      [173.07304, -41.51137],
#      [176.55861, -41.51137]]]},
#   'time_range': {'from_date': '1972-12-30T12:00:00',
# ...
#      [177.49808, -38.8258],
#      [178.38975, -38.8258]]]},
#   'time_range': {'from_date': '2024-06-28T12:00:00',
#    'to_date': '2024-08-13T12:00:00'},
#   'cf_standard_name': 'water_volume_transport_in_river_channel',
#   'precision': 0.0001,
#   'properties': {'encoding': {'streamflow': {'scale_factor': 0.0001,
#      'dtype': 'int32',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'groundwater',
#   'parameter': 'groundwater_depth',
#   'method': 'field_activity',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Northland Regional Council',
#   'aggregation_statistic': 'sporadic',
#   'frequency_interval': 'None',
#   'utc_offset': '0H',
#   'dataset_id': '87c63c869c3238e60672fd23',
#   'units': 'm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Northland Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[174.59381, -36.36405],
#      [174.59381, -34.76911],
#      [173.03166, -34.76911],
#      [173.03166, -36.36405],
#      [174.59381, -36.36405]]]},
#   'time_range': {'from_date': '1972-01-31T12:00:00',
#    'to_date': '2023-07-28T00:24:59'},
#   'cf_standard_name': 'water_table_depth',
#   'precision': 0.001,
#   'description': 'The water depth below arbirary datum.',
#   'properties': {'encoding': {'groundwater_depth': {'scale_factor': 0.001,
#      'dtype': 'int32',
#      '_FillValue': -999999},
#     'quality_code': {'dtype': 'int16', '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'groundwater',
#   'parameter': 'water_level',
#   'method': 'field_activity',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Northland Regional Council',
#   'aggregation_statistic': 'sporadic',
#   'frequency_interval': 'None',
#   'utc_offset': '0H',
#   'dataset_id': 'f1aadce545a99995c4041def',
#   'units': 'm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Northland Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[174.59381, -36.12991],
#      [174.59381, -34.76911],
#      [173.03166, -34.76911],
#      [173.03166, -36.12991],
#      [174.59381, -36.12991]]]},
#   'time_range': {'from_date': '1975-07-03T00:00:00',
#    'to_date': '2023-07-28T00:24:59'},
#   'cf_standard_name': 'water_table_depth',
#   'precision': 0.001,
#   'description': 'The water level datum is above mean sea level.',
#   'properties': {'encoding': {'water_level': {'scale_factor': 0.001,
#      'dtype': 'int32',
#      '_FillValue': -999999},
#     'quality_code': {'dtype': 'int16', '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'groundwater',
#   'parameter': 'water_level',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Northland Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '1H',
#   'utc_offset': '0H',
#   'dataset_id': '41e4c023bf16e81741527d55',
#   'units': 'm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Northland Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[174.58926, -36.12702],
#      [174.58926, -34.9175],
#      [173.18036, -34.9175],
#      [173.18036, -36.12702],
#      [174.58926, -36.12702]]]},
#   'time_range': {'from_date': '1980-07-25T04:00:00',
#    'to_date': '2023-08-17T16:00:00'},
#   'cf_standard_name': 'water_table_depth',
#   'precision': 0.001,
#   'description': 'The water level datum is above mean sea level.',
#   'properties': {'encoding': {'water_level': {'scale_factor': 0.001,
#      'dtype': 'int32',
#      '_FillValue': -999999},
#     'quality_code': {'dtype': 'int16', '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 3650}},
#  {'feature': 'groundwater',
#   'parameter': 'water_level',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Northland Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '24H',
#   'utc_offset': '12H',
#   'dataset_id': '437b9a015c475c7211c3c7e1',
#   'units': 'm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Northland Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[174.58926, -36.12702],
#      [174.58926, -34.9175],
#      [173.18036, -34.9175],
#      [173.18036, -36.12702],
#      [174.58926, -36.12702]]]},
#   'time_range': {'from_date': '1980-07-24T12:00:00',
#    'to_date': '2023-08-17T12:00:00'},
#   'cf_standard_name': 'water_table_depth',
#   'precision': 0.001,
#   'description': 'The water level datum is above mean sea level.',
#   'properties': {'encoding': {'water_level': {'scale_factor': 0.001,
#      'dtype': 'int32',
#      '_FillValue': -999999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'waterway',
#   'parameter': 'gage_height',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Northland Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '1H',
#   'utc_offset': '0H',
#   'dataset_id': '157437d0f2a027a2286c67b3',
#   'units': 'm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Northland Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[174.49348, -36.36613],
#      [174.49348, -34.62222],
#      [172.9294, -34.62222],
#      [172.9294, -36.36613],
#      [174.49348, -36.36613]]]},
#   'time_range': {'from_date': '1958-01-23T22:00:00',
#    'to_date': '2022-09-07T22:00:00'},
#   'cf_standard_name': 'water_surface_height_above_reference_datum',
#   'precision': 0.001,
#   'properties': {'encoding': {'gage_height': {'scale_factor': 0.001,
#      'dtype': 'int16',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 7300}},
#  {'feature': 'waterway',
#   'parameter': 'gage_height',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Northland Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '24H',
#   'utc_offset': '12H',
#   'dataset_id': '34a4b5397eee8bcfd15f05e7',
#   'units': 'm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Northland Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[174.49348, -36.36826],
#      [174.49348, -34.62222],
#      [172.9294, -34.62222],
#      [172.9294, -36.36826],
#      [174.49348, -36.36826]]]},
#   'time_range': {'from_date': '1958-01-23T12:00:00',
#    'to_date': '2022-09-07T12:00:00'},
#   'cf_standard_name': 'water_surface_height_above_reference_datum',
#   'precision': 0.001,
#   'properties': {'encoding': {'gage_height': {'scale_factor': 0.001,
#      'dtype': 'int16',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'waterway',
#   'parameter': 'streamflow',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Northland Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '1H',
#   'utc_offset': '0H',
#   'dataset_id': '13eab305e101197e2ba29ee2',
#   'units': 'm^3/s',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Northland Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[174.49348, -36.36613],
#      [174.49348, -34.91912],
#      [173.17026, -34.91912],
#      [173.17026, -36.36613],
#      [174.49348, -36.36613]]]},
#   'time_range': {'from_date': '1958-01-23T22:00:00',
#    'to_date': '2023-08-17T19:00:00'},
#   'cf_standard_name': 'water_volume_transport_in_river_channel',
#   'precision': 0.0001,
#   'properties': {'encoding': {'streamflow': {'scale_factor': 0.0001,
#      'dtype': 'int32',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 7300}},
#  {'feature': 'waterway',
#   'parameter': 'streamflow',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Northland Regional Council',
#   'aggregation_statistic': 'mean',
#   'frequency_interval': '24H',
#   'utc_offset': '12H',
#   'dataset_id': '64d26b2b9a7ca89591db9d1c',
#   'units': 'm^3/s',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Northland Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[174.49348, -36.36613],
#      [174.49348, -34.91912],
#      [173.17026, -34.91912],
#      [173.17026, -36.36613],
#      [174.49348, -36.36613]]]},
#   'time_range': {'from_date': '1958-01-23T12:00:00',
#    'to_date': '2023-08-17T12:00:00'},
#   'cf_standard_name': 'water_volume_transport_in_river_channel',
#   'precision': 0.0001,
#   'properties': {'encoding': {'streamflow': {'scale_factor': 0.0001,
#      'dtype': 'int32',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'atmosphere',
#   'parameter': 'precipitation',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Northland Regional Council',
#   'aggregation_statistic': 'cumulative',
#   'frequency_interval': '1H',
#   'utc_offset': '0H',
#   'dataset_id': 'ebf5b417fff8732ec9c7e2c8',
#   'units': 'mm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Northland Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[174.8, -36.43255],
#      [174.8, -34.7633],
#      [173.04599, -34.7633],
#      [173.04599, -36.43255],
#      [174.8, -36.43255]]]},
#   'time_range': {'from_date': '1905-11-01T20:00:00',
#    'to_date': '2023-08-17T21:00:00'},
#   'cf_standard_name': 'precipitation_amount',
#   'precision': 0.1,
#   'properties': {'encoding': {'precipitation': {'scale_factor': 0.1,
#      'dtype': 'int16',
#      '_FillValue': -99},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 7300}},
#  {'feature': 'atmosphere',
#   'parameter': 'precipitation',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Northland Regional Council',
#   'aggregation_statistic': 'cumulative',
#   'frequency_interval': '24H',
#   'utc_offset': '12H',
#   'dataset_id': '7c52be51e726dd13f6275d56',
#   'units': 'mm',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Northland Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[174.8, -36.43255],
#      [174.8, -34.7633],
#      [173.04599, -34.7633],
#      [173.04599, -36.43255],
#      [174.8, -36.43255]]]},
#   'time_range': {'from_date': '1905-11-01T12:00:00',
#    'to_date': '2023-08-17T12:00:00'},
#   'cf_standard_name': 'precipitation_amount',
#   'precision': 0.1,
#   'properties': {'encoding': {'precipitation': {'scale_factor': 0.1,
#      'dtype': 'int16',
#      '_FillValue': -99},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 14600}},
#  {'feature': 'waterway',
#   'parameter': 'streamflow',
#   'method': 'sensor_recording',
#   'product_code': 'quality_controlled_data',
#   'owner': 'Northland Regional Council',
#   'aggregation_statistic': 'continuous',
#   'frequency_interval': 'None',
#   'utc_offset': '0H',
#   'dataset_id': '179f6a25d0bf84997af9f39e',
#   'units': 'm^3/s',
#   'license': 'https://creativecommons.org/licenses/by/4.0/',
#   'attribution': 'Data licenced by Northland Regional Council',
#   'result_type': 'time_series',
#   'extent': {'type': 'Polygon',
#    'coordinates': [[[174.49348, -36.36613],
#      [174.49348, -34.91912],
#      [173.17026, -34.91912],
#      [173.17026, -36.36613],
#      [174.49348, -36.36613]]]},
#   'time_range': {'from_date': '1958-01-23T22:00:00',
#    'to_date': '2023-08-17T19:15:00'},
#   'cf_standard_name': 'water_volume_transport_in_river_channel',
#   'precision': 0.0001,
#   'properties': {'encoding': {'streamflow': {'scale_factor': 0.0001,
#      'dtype': 'int32',
#      '_FillValue': -9999},
#     'quality_code': {'scale_factor': 1,
#      'dtype': 'int16',
#      '_FillValue': -9999}},
#    'attrs': {'quality_code': {'standard_name': 'quality_flag',
#      'long_name': 'NEMS quality code',
#      'references': 'https://www.lawa.org.nz/media/16580/nems-quality-code-schema-2013-06-1-.pdf'}}},
#   'system_version': 4,
#   'heights': [0.0],
#   'chunk_parameters': {'block_length': 0.0, 'time_interval': 3650}}]

# %% [markdown]
# # USER INPUTS

# %%
station_ID="0854405926e3bc7e27602c86" # An example from station from Gisborne station ID
OWNER="FENZ"

# %% [markdown]
# # Step 2: GET MET DATA

# %%
# Wind Direction - WD 
my_dataset = [d for d in datasets if (d['owner'] == OWNER) and (d['parameter'] == 'wind_direction')]
dataset_id = my_dataset[0]["dataset_id"]
WD=  ts.get_results(dataset_id,station_ID) # for a specific station ID, see Data Explorer in envlib.org

# Wind Speed - WS 
my_dataset = [d for d in datasets if (d['owner'] == OWNER) and (d['parameter'] == 'wind_speed')]
dataset_id = my_dataset[0]["dataset_id"]
WS=  ts.get_results(dataset_id,station_ID) # for a specific station ID, see Data Explorer in envlib.org

# Air Temperature - T
my_dataset = [d for d in datasets if (d['owner'] == OWNER) and (d['parameter'] == 'temperature')]
dataset_id = my_dataset[0]["dataset_id"]
T=  ts.get_results(dataset_id,station_ID) # for a specific station ID, see Data Explorer in envlib.org

# Relative Humidity - RH 
my_dataset = [d for d in datasets if (d['owner'] == OWNER) and (d['parameter'] == 'relative_humidity')]
dataset_id = my_dataset[0]["dataset_id"]
RH=  ts.get_results(dataset_id,station_ID) # for a specific station ID, see Data Explorer in envlib.org

# Precipitation - Precip
my_dataset = [d for d in datasets if (d['owner'] == OWNER) and (d['parameter'] == 'precipitation')]
dataset_id = my_dataset[0]["dataset_id"]
PRC=  ts.get_results(dataset_id,station_ID) # for a specific station ID, see Data Explorer in envlib.org
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 4>()
#       2 my_dataset = [d for d in datasets if (d['owner'] == OWNER) and (d['parameter'] == 'wind_direction')]
#       3 dataset_id = my_dataset[0]["dataset_id"]
# ----> 4 WD=  ts.get_results(dataset_id,station_ID) # for a specific station ID, see Data Explorer in envlib.org
#       6 # Wind Speed - WS
#       7 my_dataset = [d for d in datasets if (d['owner'] == OWNER) and (d['parameter'] == 'wind_speed')]
#
# File /opt/conda/envs/baseline/lib/python3.9/site-packages/tethysts/main.py:543, in Tethys.get_results(self, dataset_id, station_ids, geometry, lat, lon, from_date, to_date, from_mod_date, to_mod_date, version_date, heights, bands, squeeze_dims, output_path, compression, threads)
#     540         futures.append(f)
#     541     runs = concurrent.futures.wait(futures)
# --> 543 results_list = [r.result() for r in runs[0]]
#     545 ## Clear xarray cache...because it loves caching everything...
#     546 ## This is to ensure that xarray will open the file rather than opening a cache
#     547 xr.backends.file_manager.FILE_CACHE.clear()
#
# File /opt/conda/envs/baseline/lib/python3.9/site-packages/tethysts/main.py:543, in <listcomp>(.0)
#     540         futures.append(f)
#     541     runs = concurrent.futures.wait(futures)
# --> 543 results_list = [r.result() for r in runs[0]]
#     545 ## Clear xarray cache...because it loves caching everything...
#     546 ## This is to ensure that xarray will open the file rather than opening a cache
#     547 xr.backends.file_manager.FILE_CACHE.clear()
#
# File /opt/conda/envs/baseline/lib/python3.9/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/conda/envs/baseline/lib/python3.9/concurrent/futures/_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File /opt/conda/envs/baseline/lib/python3.9/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /opt/conda/envs/baseline/lib/python3.9/site-packages/tethysts/utils.py:772, in download_results(chunk, bucket, s3, connection_config, public_url, cache, from_date, to_date, return_raw)
#     770 if chunk['key'].endswith('.zst'):
#     771     data = xr.load_dataset(s3tethys.decompress_stream_to_object(file_obj, 'zstd'))
# --> 772     hdf5tools.xr_to_hdf5(data, chunk_path)
#     773 else:
#     774     s3tethys.stream_to_file(file_obj, chunk_path)
#
# File /opt/conda/envs/baseline/lib/python3.9/site-packages/hdf5tools/main.py:146, in xr_to_hdf5(xr_dataset, new_path, group, chunks, unlimited_dims, compression)
#     143 else:
#     144     unlimited_dims = []
# --> 146 compressor = utils.get_compressor(compression)
#     148 xr_dims_list = list(xr_dataset.dims)
#     150 with h5py.File(new_path, 'w', libver='latest', rdcc_nbytes=3*1024*1024) as f:
#
# File /opt/conda/envs/baseline/lib/python3.9/site-packages/hdf5tools/utils.py:501, in get_compressor(name)
#     499     compressor = {'compression': name}
#     500 elif name == 'zstd':
# --> 501     compressor = hdf5plugin.Zstd(1)
#     502 else:
#     503     raise ValueError('name must be one of gzip, lzf, zstd, or None.')
#
# TypeError: Zstd() takes no arguments

# %%
# Wind Direction - WD 
my_dataset = [d for d in datasets if (d['owner'] == OWNER) and (d['parameter'] == 'wind_direction')]
dataset_id = my_dataset[0]["dataset_id"]
WD=  ts.get_results(dataset_id,station_ID) # for a specific station ID, see Data Explorer in envlib.org
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 4>()
#       2 my_dataset = [d for d in datasets if (d['owner'] == OWNER) and (d['parameter'] == 'wind_direction')]
#       3 dataset_id = my_dataset[0]["dataset_id"]
# ----> 4 WD=  ts.get_results(dataset_id,station_ID)
#
# File /opt/conda/envs/baseline/lib/python3.9/site-packages/tethysts/main.py:543, in Tethys.get_results(self, dataset_id, station_ids, geometry, lat, lon, from_date, to_date, from_mod_date, to_mod_date, version_date, heights, bands, squeeze_dims, output_path, compression, threads)
#     540         futures.append(f)
#     541     runs = concurrent.futures.wait(futures)
# --> 543 results_list = [r.result() for r in runs[0]]
#     545 ## Clear xarray cache...because it loves caching everything...
#     546 ## This is to ensure that xarray will open the file rather than opening a cache
#     547 xr.backends.file_manager.FILE_CACHE.clear()
#
# File /opt/conda/envs/baseline/lib/python3.9/site-packages/tethysts/main.py:543, in <listcomp>(.0)
#     540         futures.append(f)
#     541     runs = concurrent.futures.wait(futures)
# --> 543 results_list = [r.result() for r in runs[0]]
#     545 ## Clear xarray cache...because it loves caching everything...
#     546 ## This is to ensure that xarray will open the file rather than opening a cache
#     547 xr.backends.file_manager.FILE_CACHE.clear()
#
# File /opt/conda/envs/baseline/lib/python3.9/concurrent/futures/_base.py:439, in Future.result(self, timeout)
#     437     raise CancelledError()
#     438 elif self._state == FINISHED:
# --> 439     return self.__get_result()
#     441 self._condition.wait(timeout)
#     443 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/conda/envs/baseline/lib/python3.9/concurrent/futures/_base.py:391, in Future.__get_result(self)
#     389 if self._exception:
#     390     try:
# --> 391         raise self._exception
#     392     finally:
#     393         # Break a reference cycle with the exception in self._exception
#     394         self = None
#
# File /opt/conda/envs/baseline/lib/python3.9/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /opt/conda/envs/baseline/lib/python3.9/site-packages/tethysts/utils.py:772, in download_results(chunk, bucket, s3, connection_config, public_url, cache, from_date, to_date, return_raw)
#     770 if chunk['key'].endswith('.zst'):
#     771     data = xr.load_dataset(s3tethys.decompress_stream_to_object(file_obj, 'zstd'))
# --> 772     hdf5tools.xr_to_hdf5(data, chunk_path)
#     773 else:
#     774     s3tethys.stream_to_file(file_obj, chunk_path)
#
# File /opt/conda/envs/baseline/lib/python3.9/site-packages/hdf5tools/main.py:146, in xr_to_hdf5(xr_dataset, new_path, group, chunks, unlimited_dims, compression)
#     143 else:
#     144     unlimited_dims = []
# --> 146 compressor = utils.get_compressor(compression)
#     148 xr_dims_list = list(xr_dataset.dims)
#     150 with h5py.File(new_path, 'w', libver='latest', rdcc_nbytes=3*1024*1024) as f:
#
# File /opt/conda/envs/baseline/lib/python3.9/site-packages/hdf5tools/utils.py:501, in get_compressor(name)
#     499     compressor = {'compression': name}
#     500 elif name == 'zstd':
# --> 501     compressor = hdf5plugin.Zstd(1)
#     502 else:
#     503     raise ValueError('name must be one of gzip, lzf, zstd, or None.')
#
# TypeError: Zstd() takes no arguments

# %%
WS.time[0], WD.sizes, T.sizes, WS.sizes, RH.sizes
# Out:
# (<xarray.DataArray 'time' ()>
#  array('2017-02-20T23:00:00.000000000', dtype='datetime64[ns]')
#  Coordinates:
#      time     datetime64[ns] 2017-02-20T23:00:00
#  Attributes:
#      DIMENSION_LABELS:  time
#      dtype:             int64
#      dtype_decoded:     datetime64[s],
#  Frozen({'geometry': 1, 'height': 1, 'time': 44911}),
#  Frozen({'geometry': 1, 'height': 1, 'time': 44978}),
#  Frozen({'geometry': 1, 'height': 1, 'time': 44978}),
#  Frozen({'geometry': 1, 'height': 1, 'time': 44978}))

# %%
PRC.sizes, WD.sizes, T.sizes, WS.sizes, RH.sizes
# Out:
# (Frozen({'geometry': 1, 'height': 1, 'time': 41735}),
#  Frozen({'geometry': 1, 'height': 1, 'time': 44911}),
#  Frozen({'geometry': 1, 'height': 1, 'time': 44978}),
#  Frozen({'geometry': 1, 'height': 1, 'time': 44978}),
#  Frozen({'geometry': 1, 'height': 1, 'time': 44978}))

# %%
ds = xr.merge([WS, WD, T, RH,PRC])
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 ds = xr.merge([WS, WD, T, RH,PRC])
#
# File /opt/conda/envs/baseline02/lib/python3.11/site-packages/xarray/core/merge.py:992, in merge(objects, compat, join, fill_value, combine_attrs)
#     989         obj = obj.to_dataset()
#     990     dict_like_objects.append(obj)
# --> 992 merge_result = merge_core(
#     993     dict_like_objects,
#     994     compat,
#     995     join,
#     996     combine_attrs=combine_attrs,
#     997     fill_value=fill_value,
#     998 )
#     999 return Dataset._construct_direct(**merge_result._asdict())
#
# File /opt/conda/envs/baseline02/lib/python3.11/site-packages/xarray/core/merge.py:719, in merge_core(objects, compat, join, combine_attrs, priority_arg, explicit_coords, indexes, fill_value, skip_align_args)
#     717 collected = collect_variables_and_indexes(aligned, indexes=indexes)
#     718 prioritized = _get_priority_vars_and_indexes(aligned, priority_arg, compat=compat)
# --> 719 variables, out_indexes = merge_collected(
#     720     collected, prioritized, compat=compat, combine_attrs=combine_attrs
#     721 )
#     723 dims = calculate_dimensions(variables)
#     725 coord_names, noncoord_names = determine_coords(coerced)
#
# File /opt/conda/envs/baseline02/lib/python3.11/site-packages/xarray/core/merge.py:290, in merge_collected(grouped, prioritized, compat, combine_attrs, equals)
#     288 variables = [variable for variable, _ in elements_list]
#     289 try:
# --> 290     merged_vars[name] = unique_variable(
#     291         name, variables, compat, equals.get(name, None)
#     292     )
#     293 except MergeError:
#     294     if compat != "minimal":
#     295         # we need more than "minimal" compatibility (for which
#     296         # we drop conflicting coordinates)
#
# File /opt/conda/envs/baseline02/lib/python3.11/site-packages/xarray/core/merge.py:144, in unique_variable(name, variables, compat, equals)
#     141                 break
#     143 if not equals:
# --> 144     raise MergeError(
#     145         f"conflicting values for variable {name!r} on objects to be combined. "
#     146         "You can skip this check by specifying compat='override'."
#     147     )
#     149 if combine_method:
#     150     for var in variables[1:]:
#
# MergeError: conflicting values for variable 'ref' on objects to be combined. You can skip this check by specifying compat='override'.

# %%
ds.time[-1]
# Out:
# <xarray.DataArray 'time' ()>
# array('2024-07-01T18:00:00.000000000', dtype='datetime64[ns]')
# Coordinates:
#     time     datetime64[ns] 2024-07-01T18:00:00
# Attributes:
#     DIMENSION_LABELS:  time
#     dtype:             int64
#     dtype_decoded:     datetime64[s]

# %% [markdown]
# # Step 3: SAVE to NETCDF

# %%
# saving dataset into one netcdf file
ds.to_netcdf("AWS_Data.nc", mode="w",format='NETCDF4')
